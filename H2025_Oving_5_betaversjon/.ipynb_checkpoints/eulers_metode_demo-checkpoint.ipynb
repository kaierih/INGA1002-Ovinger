# %% [markdown]
# ## Demo av Eulers Metode
#
#
#
# Kjør kodecellen nedenfor for å se en interaktiv demo for løsning av initialverdiproblemet $y´ =-y, \ \ \ y(0) = 10$

# %%
from numerikk_demoer import EulerDemo1D
# %matplotlib ipympl
def f(x, y):
    return -y

temp = EulerDemo1D(f, y0=1.0, x0=0.0, xN = 10.0, fig_num=1)
