# %% [markdown]
# # Øving 2
#
# Hei og velkommen til andre øving i Programmeringsdelen av emnet INGA1002 - Programmering, numerikk og sikkerhet. Et overordnet tema for denne øvingen er ***numerisk derivasjon***, som kan brukes til å regne ut den deriverte av funksjoner, datasett o.l. i Python. Av praktisk programmeringskunnskap skal vi bli kjent med *sekvenstypene* `list` og spesielt `numpy` sin `array`, som er elementære for å kunne analysere og visualisere data, gjøre simuleringer i en rekke fagfelt, og mye mer.
#
# Kjører du kodecellen nedenfor, vil du se en interaktiv demo som illustrerer hvordan de ulike metodene for å finne en tilnærmet verdi av den deriverte til funksjonen $f(x) = x^3 - 2\cdot x^2 + 1$ fungerer.

# %%
from numerikk_demoer import NumDiffDemo
# %matplotlib ipympl

def f_1(x):
    y = x**3-2*x**2 +1
    return y

NumDiffDemo(func = f_1, xlim = (0, 2), fig_num = 1);

# %% [markdown]
# ## Læringsmål
# ### Numerikk
# - Forstå konseptet numerisk derivasjon
# - Bli kjent med de ulike metodene for numerisk derivasjon: Foroverdifferanse, Bakoverdifferanse og Senterdifferanse
# - Grunnleggende om nøyaktighet i numeriske beregninger.
# ### Programmering
# - Bli kjent med sekvenstyper som `list` og `np.array`, og hva forskjellene på disse er.
# - Forstå hvordan å bruke numpy-arrays i vanlige funksjoner, for å utføre beregninger på flere verdier samtidig.
# - Plotting og visualisere funksjoner/datasett.

# %% [markdown]
# ## Om oppgavene
#
# Oppgaver markert som "grunnleggende" dekker tema som er regnet som kjernepensum, og er nødvendig å beherske for å gå videre med øving 3 og oppover. Andre oppgaver vil absolutt styrke forståelsen for faget, og kan ofte være mer spennende å jobbe med, men er i større grad frivillig å arbeide med. Er du ny til programmering, er det anbefalt å begynne med de grunnleggende oppgavene, men om du har programmert litt før, kan det være mer spennende å arbeide med de øvrige oppgavene.
#
# Alle oppgavene til sammen kan gi inntil 90 poeng. Kravet for godkjenning er 40 poeng eller mer.

# %% [markdown]
# Oppgave | Tema | Merknad |Poeng
# --- | --- | --- | ---
# [Intro til Numerisk Derivasjon](1_Numerisk_derivasjon_intro.ipynb) | Numerisk derivasjon med enkeltverdier | Grunnleggende | 10
# [Intro til Lister](1_Intro_til_lister.ipynb) | Lister og indeksering | Grunnleggende | 10
# [Introduksjon til Numpy](4_Numpy_intro.ipynb) | Numpy-arrays og elementvise regneoperasjoner | Grunnleggende | 10
# [Ofte brukte arrays](5_Ofte_brukte_arrays.ipynb) | Generering av tallrekker med Numpy | Grunnleggende men litt innviklet | 10
# [Plotting intro](6_Plotting_1.ipynb) | Hvordan tegne grafer av matematiske funksjoner | Grunnleggende | 10
# [Numerisk derivasjon med arrays](6_Numerisk_derivasjon_med_arrays.ipynb) | Sammenligning av numeriske derivasjonsmetoder med `numpy` og plotting | Grunnleggende | 10
# [Viderekommen plotting](7_Plotting_2.ipynb) | Styling av grafer, sammensetting av flere kurver | Kjekt å kunne | 10
# [Dataanalyse med Python](8_Dataanalyse.ipynb) | Grunnleggende analyse av datasett med Python | Kjekt å kunne og litt komplisert | 10
# [Logaritmisk plotting](9_Plotting_3.ipynb) | Logaritmisk skalering av akser, flere plot i samme figur | Kjekt å kunne men komplisert | 10
# <!--[Konvergensrate for numerisk derivasjon](9_Numerisk_derivasjon_konvergens.ipynb) | Skrittlengde i numerisk derivasjon, og analyse av nujmerisk feil | Nyttig men litt komplisert| 10-->

# %% [markdown]
# ### For å generere tilbakemelding på oppgavesvar, kjør kodecellen nedenfor:
#
# *NB! Husk å lagre alle oppgavefilene før du kjører retting*

# %%
# Make sure autofeedback package is installed
try:
    from autofeedback import autograde_notebooks
except ModuleNotFoundError:
    print("Installing autofeedback. Please Wait...")
    output = !pip install git+https://github.com/kaierih/autofeedback.git
    from autofeedback import autograde_notebooks
    print("Autofeedback installed.")

# Generate feedback from grading tests
task_files = ["1_Numerisk_derivasjon_intro.ipynb",
              "2_Intro_til_lister.ipynb",
              "3_Numpy_intro.ipynb",
              "4_Ofte_brukte_arrays.ipynb",
              "5_Plotting_1.ipynb",
              "6_Numerisk_derivasjon_med_arrays.ipynb",
              "7_Plotting_2.ipynb",
              "8_Dataanalyse.ipynb",
              "9_Plotting_3.ipynb"]
autograde_notebooks(task_files)
