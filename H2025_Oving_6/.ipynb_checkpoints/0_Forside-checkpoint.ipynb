# %% [markdown]
# # Øving 6
#
# Hei og velkommen til sjette øving i INGA1002 - Programmering, numerikk og sikkerhet. Et overordnet tema for denne øvingen er ***numersik løsning av ligninger*** ved hjelp av en metode som heter ***[fikspunktiterasjon](https://github.com/imfdrift/INGX1002H24/blob/01d7838a7c89b45b0fe2686cb70275ddab1b9bc9//2_lignlos/2_lignlos_fikspunkt.ipynb)***. I denne øvingen vil dere først bli introdusert for fikspunktiterasjon som konsept. Deretter vil dere arbeide med selvstendige oppgaver der **while-løkker** står i fokus, som er en ny type løkke som lar oss repetere kode når antallet repetisjoner ikke er forhåndsbestemt. Til slutt vil vi ta i bruk while-løkker til å utføre ligningsløsning med fikspunktiterasjon på en mer elegant måte.
#
# #### Fikspunktiterasjon illustrert
# Kjører du kodecellen nedenfor, kan du se hvordan fikspunktiterasjon "peiler seg inn" på løsningen for ligningen $x = g(x)$ der funksjonen $g(x) = \cos(x)$ og algoritmen starter i $x_0 = 0.5$:

# %%
from numerikk_demoer import FixedPointDemo
from numpy import cos
# %matplotlib widget

def g(x):
    return cos(x)

FixedPointDemo(g, x0=0.0, N=10);

# %% [markdown]
# ## Læringsmål
#
# - Forstå hva fikspunktiterasjon
# - Erfare at numerisk ligningsløsning kan oppføre seg ulikt avhengig av situasjon
# - Betingelses-styrte løkker (While-løkker)

# %% [markdown]
# ## Om oppgavene
#
# Oppgaver markert som "grunnleggende" dekker tema som er regnet som kjernepensum, og vil med stor sannsynlighet være aktuell for numerikk senere. Andre oppgaver vil absolutt styrke forståelsen for faget, og kan ofte være mer spennende å jobbe med, men er i større grad frivillig å arbeide med. Er du ny til programmering, er det anbefalt å begynne med de grunnleggende oppgavene, men om du har programmert litt før, kan det være mer spennende å arbeide med de øvrige oppgavene.
#
# Alle oppgavene til sammen kan gi inntil 70 poeng. Kravet for godkjenning er 40 poeng eller mer.

# %% [markdown]
# Oppgave | Tema | Merknad | Poeng
# --- | --- | --- | ---
# [Intro til Fikspunktiterasjon](1_Fikspunkt_intro.ipynb) | Hva er fikspunktiterasjon? | Grunnleggende | 10
# [While intro](2_while_intro.ipynb) | Intro til betingelsesstyrte løkker | Grunnleggende | 10
# [Simulering av terningkast](3_terningkast.ipynb) | While-løkker og tilfeldige tall | Grunnleggende | 10
# [Nedbetaling av lån](4_Nedbetaling_av_laan.ipynb) | While-løkker med oppsamling | Grunnleggende, litt krevende | 10
# [Fikspunktiterasjon med while-løkke](5_Fikspunkt_while.ipynb) | Ligningsløsing med betingelses-styrte iterasjoner | Grunnleggende | 10
# [Konvens for fikspunktiterasjon](6_Fikspunkt_konvergens.ipynb) | Situasjoner der fikspunktiterasjon vil mislykkes i å finne en løsning | Grunnleggende, litt krevende | 10
# [Eulers metode med while-løkke](7_Eulers_metode_while.ipynb) | Eulers metode når sluttid for simulering er ukjent | Litt avansert | 10

# %%
# Make sure autofeedback package is installed
try:
    from autofeedback import autograde_notebooks
except ModuleNotFoundError:
    print("Installing autofeedback. Please Wait...")
    output = !pip install git+https://github.com/kaierih/autofeedback.git
    from autofeedback import autograde_notebooks
    print("Autofeedback installed.")

# Generate feedback from grading tests
task_files = ["1_Fikspunkt_intro.ipynb",
              "2_while_intro.ipynb",
              "3_terningkast.ipynb",
              "4_Nedbetaling_av_laan.ipynb",
              "5_Fikspunkt_while.ipynb",
              "6_Fikspunkt_konvergens.ipynb",
              "7_Eulers_metode_while.ipynb"]
autograde_notebooks(task_files)
